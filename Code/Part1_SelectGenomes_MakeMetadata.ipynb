# %%
import csv

# %% [markdown]
# ### Selection of genomic assemblies and their downloading

# %% [markdown]
# Parsing the list of genomes, obtained from NCBI FTP on June 2023
#
# https://ftp.ncbi.nlm.nih.gov/genomes/ASSEMBLY_REPORTS/assembly_summary_genbank.txt
#
# See ftp://ftp.ncbi.nlm.nih.gov/genomes/README_assembly_summary.txt for a description of the columns in this file.
#
# #assembly_accession	bioproject	biosample	wgs_master	refseq_category	taxid	species_taxid	organism_name	infraspecific_name	isolate	version_status	assembly_level	release_type	genome_rep	seq_rel_date	asm_name	asm_submitter	gbrs_paired_asm	paired_asm_comp	ftp_path	excluded_from_refseq	relation_to_type_material	asm_not_live_date	assembly_type	group	genome_size	genome_size_ungapped	gc_percent	replicon_count	scaffold_count	contig_count	annotation_provider	annotation_name	annotation_date	total_gene_count	protein_coding_gene_count	non_coding_gene_count	pubmed_id

# %%
ftp = {}
latin = {}
names = []
rep = {}
with open('assembly_summary_genbank.txt') as file1:
    for line in file1:
        if not line.startswith('#') and 'ExonCaptKit' not in line:
            dat = line.strip().split('\t')
            if dat[20] == 'na' and dat[13] == 'Full':
                if dat[4] == 'representative genome':
                    rep[dat[7]] = dat[19]
                if dat[7] not in ftp:
                    ftp[dat[7]] = []
                ftp[dat[7]].append(dat[19])
                latin[dat[19].split('/')[-1]] = [dat[7],dat[6]]
                names.append(dat[7])
print(len(names),len(set(names)),len(rep))
# Out:
# 2066 622 577

# %%
# Write down the path to the assembly, 'ftp_path' column
out = open('FTP_for_genomes','w')

for item in names:
    if item in rep and item != 'Canis lupus familiaris':
        out.write(rep[item] + '/' + rep[item].split('/')[-1] + '_genomic.fna.gz\n')
    else:
        for indi in ftp[item]:
            out.write(indi + '/' + indi.split('/')[-1] + '_genomic.fna.gz\n')

out.close()

# Run wget to download assemblies from the file
# for item in `cat FTP_for_genomes`; do wget "$item"; done

# %%
# Make the file (Namesystem) connecting genome IDs with species names and their taxid
# GCF_000151735.1_Cavpor3.0	Cavia porcellus	10141

genomes = []
with open('FTP_for_genomes') as file1:
    for line in file1:
        genomes.append(line.split('/')[-2])
        
out = open('Namesystem','w')
for item in genomes:
    out.write(item + '\t' + '\t'.join(latin[item]) + '\n')
out.close()

# %% [markdown]
# ### Retrieving approximate genomic coordinates for NEAT1 and MALAT1 orthologs

# %%
#### Set of commands which were run in command line outside of python

# cut -f 1 Namesystem > liblist

# for i in `cat liblist`; do makeblastdb -in ./downloads/"$i"_genomic.fna -dbtype 'nucl'; 
# blastn -query known_NEAT1_MALAT1_and_features.fasta -db ./downloads/"$i"_genomic.fna -task blastn
# -out ./BLAST_features/"$i".txt -max_target_seqs 3  
# -outfmt "6 qseqid sseqid length pident qstart qend sstart send evalue bitscore" -max_hsps 3; done

# %%
with open('liblist') as file1:
    libs = file1.read().split('\n')[:-1]

# %%
NEAT = {}
MALAT = {}
# headers of sequences in 'known_NEAT1_MALAT1_and_features.fasta' grouped by types
# group of known NEAT1 orthologs
a = ['Human_NEAT1','Marsupials_NEAT1','Mouse_NEAT1']
# group of known MALAT1 orthologs
b = ['Human_MALAT1','Mouse_MALAT1']
# group of NEAT1 tRNA-like structures
c = ['AfterTriplex_Human_NEAT1','AfterTriplex_Marsupials_NEAT1','AfterTriplex_Mouse_NEAT1']
# group of MALAT1 promotor areas
d = ['MALAT_start_human','MALAT_start_mouse','MALAT_Tata']
# group of NEAT1 promotor areas
d1 = ['Marsupials_NEAT1_start','NEAT_Tata']

# Parsing blastn outputs to identify approximate coordinates of orthologs
for lib in libs:
    with open('./BLAST_features/' + lib + '.txt') as file1:
        N = {}
        M = {}
        N_start = {}
        M_start = {}
        N_stop = {}
        M_stop = {}
        NTata = {}
        MTata = {}
        NTrip = {}
        MTrip = {}
        
        for line in file1:
            dat = line.strip().split('\t')
            if dat[0] in a:
                if dat[1] not in N:
                    N[dat[1]] = 0
                N[dat[1]] += int(dat[2])
                if dat[4] == '1':
                    N_start[dat[1]] = dat[6]
            if dat[0] in b:
                if dat[1] not in M:
                    M[dat[1]] = 0
                M[dat[1]] += int(dat[2])
                if dat[4] == '1':
                    M_start[dat[1]] = dat[6]
            if dat[0] in d1 and int(dat[2]) > 30 and dat[1] not in NTata:
                NTata[dat[1]] = dat[6]
            if dat[0] in d and int(dat[2]) > 30 and dat[1] not in MTata:
                MTata[dat[1]] = dat[6]
            if dat[0] == 'AfterTriplex_Human_MALAT1' and dat[4] == '1' and dat[1] not in M_stop:
                M_stop[dat[1]] = dat[6]
            if dat[0] in c and dat[4] == '1' and dat[1] not in N_stop:
                N_stop[dat[1]] = dat[6]
            if dat[0] == 'NEAT_triplex' and dat[5] == '52' and dat[1] not in NTrip:
                NTrip[dat[1]] = dat[7]
            if dat[0] == 'MALAT_triplex' and dat[5] == '92' and dat[1] not in MTrip:
                MTrip[dat[1]] = dat[7]
                
        # Summarise the results of parsing
        Ncont = sorted(N.keys(), key=lambda kv: N[kv],reverse=True)[0]
        Mcont = sorted(M.keys(), key=lambda kv: M[kv],reverse=True)[0]
        if Ncont == Mcont:
            NEAT[lib] = {'contig': Ncont}
            MALAT[lib] = {'contig': Mcont}
        else:
            Ncont = Mcont
            NEAT[lib] = {'contig': 'FromMALAT_' + Ncont}
            MALAT[lib] = {'contig': Mcont}
            
        if Ncont in NTata:
            NEAT[lib]['start'] = NTata[Ncont]
        else:
            if Ncont in N_start:
                NEAT[lib]['start'] = N_start[Ncont]
            else:
                print(lib,'No NEAT start')
        if Ncont in MTata:
            MALAT[lib]['start'] = MTata[Ncont]
        else:
            if Ncont in M_start:
                MALAT[lib]['start'] = M_start[Ncont]
            else:
                print(lib,'No MALAT start')
        if Ncont in N_stop:
            NEAT[lib]['stop'] = N_stop[Ncont]
        else:
            if Ncont in NTrip:
                NEAT[lib]['stop'] = NTrip[Ncont]
            else:
                print(lib,'No NEAT stop')
        if Ncont in M_stop:
            MALAT[lib]['stop'] = M_stop[Ncont]
        else:
            if Ncont in MTrip:
                MALAT[lib]['stop'] = MTrip[Ncont]
            else:
                print(lib,'No MALAT stop')
# Out:
# GCA_000002285.4_Dog10K_Boxer_Tasha No MALAT start
# GCA_000152225.2_Pcap_2.0 No MALAT start
# GCA_000164785.2_C_hoffmanni-2.0.1 No NEAT start
# GCA_000164785.2_C_hoffmanni-2.0.1 No MALAT start
# GCA_000164785.2_C_hoffmanni-2.0.1 No NEAT stop
# GCA_000181375.1_ASM18137v1 No NEAT start
# GCA_000181375.1_ASM18137v1 No MALAT start
# GCA_000181375.1_ASM18137v1 No NEAT stop
# GCA_000181375.1_ASM18137v1 No MALAT stop
# GCA_000181415.1_ASM18141v1 No NEAT start
# GCA_000181415.1_ASM18141v1 No MALAT start
# GCA_000181415.1_ASM18141v1 No NEAT stop
# GCA_000181415.1_ASM18141v1 No MALAT stop
# GCA_000331495.1_Beagle No NEAT start
# GCA_000331495.1_Beagle No MALAT start
# GCA_000331495.1_Beagle No NEAT stop
# GCA_000331495.1_Beagle No MALAT stop
# GCA_000465285.1_ASM46528v1 No NEAT start
# GCA_000465285.1_ASM46528v1 No NEAT stop
# GCA_000688575.1_CavAp1.0 No NEAT start
# GCA_000688575.1_CavAp1.0 No MALAT start
# GCA_000688575.1_CavAp1.0 No MALAT stop
# GCA_000754665.1_Bison_UMD1.0 No NEAT start
# GCA_000754665.1_Bison_UMD1.0 No NEAT stop
# GCA_000978805.1_ASM97880v1 No NEAT start
# GCA_000978805.1_ASM97880v1 No NEAT stop
# GCA_001262655.1_Emacaco_refEf_BWA_oneround No NEAT start
# GCA_001262655.1_Emacaco_refEf_BWA_oneround No NEAT stop
# GCA_001262665.1_Eflavifronsk33QCA No NEAT start
# GCA_001262665.1_Eflavifronsk33QCA No NEAT stop
# GCA_001458135.2_marMar No NEAT start
# GCA_001675575.1_ASM167557v1 No MALAT stop
# GCA_001685095.1_ETalpinus_0.1 No NEAT start
# GCA_001685095.1_ETalpinus_0.1 No NEAT stop
# GCA_002197005.1_CerEla1.0 No NEAT start
# GCA_002335545.1_Aspe_assembly01 No NEAT start
# GCA_002335545.1_Aspe_assembly01 No NEAT stop
# GCA_002564285.1_Tym_barrerae_AO245_v1 No NEAT start
# GCA_002564285.1_Tym_barrerae_AO245_v1 No MALAT start
# GCA_002564285.1_Tym_barrerae_AO245_v1 No NEAT stop
# GCA_002564305.1_Oct_mimax_AO248_v1 No NEAT start
# GCA_002564305.1_Oct_mimax_AO248_v1 No MALAT start
# GCA_002564305.1_Oct_mimax_AO248_v1 No NEAT stop
# GCA_002564305.1_Oct_mimax_AO248_v1 No MALAT stop
# GCA_002901085.1_ASM290108v1 No MALAT start
# GCA_002995585.1_ASM299558v1 No NEAT start
# GCA_002995585.1_ASM299558v1 No NEAT stop
# GCA_003033725.1_ASM303372v1 No NEAT start
# GCA_003033725.1_ASM303372v1 No NEAT stop
# GCA_003118495.1_macFus_1.0 No NEAT start
# GCA_003118495.1_macFus_1.0 No NEAT stop
# GCA_003182575.1_ASM318257v1 No NEAT start
# GCA_003182575.1_ASM318257v1 No NEAT stop
# GCA_003254725.2_ASM325472v2 No MALAT start
# GCA_004365215.1_CunPac_v1_BIUU No NEAT stop
# GCA_004886185.2_Basenji_breed-1.1 No MALAT start
# GCA_005280165.1_ASM528016v1 No MALAT stop
# GCA_005406085.2_Prionailurus_bengalensis_euptilurus_v03 No NEAT start
# GCA_005406085.2_Prionailurus_bengalensis_euptilurus_v03 No NEAT stop
# GCA_005458795.1_GSC_VIM_1.0 No NEAT start
# GCA_005458795.1_GSC_VIM_1.0 No MALAT start
# GCA_006408545.1_HBT No NEAT start
# GCA_006408545.1_HBT No MALAT start
# GCA_006408545.1_HBT No NEAT stop
# GCA_006408545.1_HBT No MALAT stop
# GCA_006408615.1_BWD No NEAT start
# GCA_006408615.1_BWD No NEAT stop
# GCA_006408675.1_KDD No NEAT start
# GCA_006408675.1_KDD No NEAT stop
# GCA_006408735.1_CMD No MALAT start
# GCA_006408755.1_TMG No NEAT start
# GCA_006408755.1_TMG No NEAT stop
# GCA_006410495.1_BUB No NEAT start
# GCA_006410495.1_BUB No MALAT start
# GCA_006410495.1_BUB No NEAT stop
# GCA_006410495.1_BUB No MALAT stop
# GCA_006410555.1_IBX No NEAT start
# GCA_006410555.1_IBX No MALAT start
# GCA_006410555.1_IBX No NEAT stop
# GCA_006410555.1_IBX No MALAT stop
# GCA_006410615.1_SUN No NEAT start
# GCA_006410615.1_SUN No MALAT start
# GCA_006410615.1_SUN No NEAT stop
# GCA_006410615.1_SUN No MALAT stop
# GCA_006410655.1_DFW No NEAT start
# GCA_006410655.1_DFW No NEAT stop
# GCA_006410675.1_KSP No NEAT start
# GCA_006410675.1_KSP No MALAT start
# GCA_006410675.1_KSP No NEAT stop
# GCA_006410695.1_MXD No NEAT start
# GCA_006410695.1_MXD No MALAT stop
# GCA_006410775.1_LEK No NEAT start
# GCA_006410775.1_LEK No MALAT start
# GCA_006410775.1_LEK No NEAT stop
# GCA_006410775.1_LEK No MALAT stop
# GCA_006410875.1_RAL No NEAT start
# GCA_006410875.1_RAL No MALAT start
# GCA_006410875.1_RAL No NEAT stop
# GCA_006410935.1_BHR No NEAT start
# GCA_006410935.1_BHR No MALAT start
# GCA_006410935.1_BHR No NEAT stop
# GCA_006410935.1_BHR No MALAT stop
# GCA_006411685.1_MTN No NEAT start
# GCA_006411685.1_MTN No NEAT stop
# GCA_006411685.1_MTN No MALAT stop
# GCA_006416875.1_CME No NEAT start
# GCA_006416875.1_CME No MALAT start
# GCA_006416875.1_CME No NEAT stop
# GCA_006417275.1_ORB No NEAT start
# GCA_006417275.1_ORB No MALAT start
# GCA_006417275.1_ORB No NEAT stop
# GCA_006417275.1_ORB No MALAT stop
# GCA_006461725.1_NPU_MCHR_1.0 No NEAT start
# GCA_006461725.1_NPU_MCHR_1.0 No NEAT stop
# GCA_007455615.1_ASM745561v1 No NEAT start
# GCA_007455615.1_ASM745561v1 No NEAT stop
# GCA_007922755.1_PedCap_v1_BIUU No NEAT start
# GCA_007922755.1_PedCap_v1_BIUU No NEAT stop
# GCA_007922795.1_NycHum_v1_BIUU No NEAT start
# GCA_017311455.1_Otocyon_megalotis_TS305_17_09_2019 No MALAT start
# GCA_017311455.1_Otocyon_megalotis_TS305_17_09_2019 No NEAT stop
# GCA_018403415.1_P_iriomotensis_scaffold_01 No NEAT start
# GCA_019843815.1_ASM1984381v1 No NEAT start
# GCA_019843815.1_ASM1984381v1 No NEAT stop
# GCA_019843835.1_ASM1984383v1 No NEAT start
# GCA_019843835.1_ASM1984383v1 No MALAT start
# GCA_019843835.1_ASM1984383v1 No NEAT stop
# GCA_019843835.1_ASM1984383v1 No MALAT stop
# GCA_019843855.1_ASM1984385v1 No NEAT start
# GCA_019843855.1_ASM1984385v1 No MALAT start
# GCA_019843855.1_ASM1984385v1 No NEAT stop
# GCA_019843855.1_ASM1984385v1 No MALAT stop
# GCA_019844195.1_ASM1984419v1 No MALAT stop
# GCA_019903745.2_ULRtarCaribou_2v2 No NEAT start
# GCA_019903745.2_ULRtarCaribou_2v2 No NEAT stop
# GCA_019903745.2_ULRtarCaribou_2v2 No MALAT stop
# GCA_020387435.1_ASM2038743v1 No NEAT start
# GCA_020392405.1_ASM2039240v1 No MALAT start
# GCA_020740815.1_VCOM_Snig_1.0 No NEAT start
# GCA_020740815.1_VCOM_Snig_1.0 No NEAT stop
# GCA_020854095.1_UniMelb_DasViv_v1.0 No MALAT start
# GCA_021234165.1_CSHL_Meso_final No MALAT start
# GCA_021461705.1_Cryptotis_parva_assembly_1.0 No NEAT start
# GCA_021461705.1_Cryptotis_parva_assembly_1.0 No NEAT stop
# GCA_021461705.1_Cryptotis_parva_assembly_1.0 No MALAT stop
# GCA_023159225.1_ASM2315922v1 No NEAT start
# GCA_023170115.1_Speothos_venaticus_v01 No NEAT start
# GCA_023170115.1_Speothos_venaticus_v01 No MALAT start
# GCA_023170115.1_Speothos_venaticus_v01 No NEAT stop
# GCA_023548195.1_mBetpen1.pri.20210916 No MALAT start
# GCA_023553655.1_mMyrfas1.20211206 No MALAT start
# GCA_023553655.1_mMyrfas1.20211206 No NEAT stop
# GCA_023764695.1_ASM2376469v1 No NEAT stop
# GCA_023783135.1_ASM2378313v1 No MALAT start
# GCA_023783435.1_ASM2378343v1 No MALAT start
# GCA_023783475.1_ASM2378347v1 No MALAT start
# GCA_023898255.1_ASM2389825v1 No MALAT start
# GCA_024139225.1_mSunEtr1.pri.cur No NEAT start
# GCA_024363435.1_mPerLon1.0.a No NEAT start
# GCA_024363435.1_mPerLon1.0.a No MALAT start
# GCA_024363575.1_mPerLon1.0.p No NEAT start
# GCA_024363575.1_mPerLon1.0.p No MALAT start
# GCA_024711535.1_mDipMer1.0.p No NEAT start
# GCA_024803745.1_mThoBot1.0.p No NEAT start
# GCA_024803745.1_mThoBot1.0.p No MALAT start
# GCA_025584935.1_MNHNYannick_LA_1 No NEAT start
# GCA_025584935.1_MNHNYannick_LA_1 No NEAT stop
# GCA_026826555.1_mTolMat1 No MALAT start
# GCA_027406575.1_mNycCou1.pri No MALAT start
# GCA_027563665.1_DD_ASM_mAP_20210503 No MALAT start
# GCA_028533205.1_Lagorchestes_hirsutus_HiC No MALAT start
# GCA_028533215.1_Babyrousa_celebensis_HiC No NEAT start
# GCA_028533215.1_Babyrousa_celebensis_HiC No NEAT stop
# GCA_028533335.1_Chrysocyon_brachyurus_HiC No MALAT start
# GCA_028533375.1_Diceros_bicornis_HiC No NEAT start
# GCA_028533375.1_Diceros_bicornis_HiC No MALAT start
# GCA_028533765.1_Pteropus_rufus_HiC No MALAT start
# GCA_028533885.1_Nasua_narica_HiC No NEAT stop
# GCA_028533885.1_Nasua_narica_HiC No MALAT stop
# GCA_028534055.1_Eulemur_mongoz_HiC No MALAT start
# GCA_028565675.1_ASM2856567v1 No MALAT start
# GCA_028583105.1_mf-2k No NEAT start
# GCA_028583685.1_PetGlider_PUasm1.0 No MALAT start
# GCA_028627135.1_Pseudochirops_cupreus_HiC No MALAT start
# GCA_028627135.1_Pseudochirops_cupreus_HiC No NEAT stop
# GCA_028627215.1_mg-2k No NEAT start
# GCA_028627265.1_Cercopithecus_mitis_HiC No NEAT start
# GCA_028627265.1_Cercopithecus_mitis_HiC No NEAT stop
# GCA_028644305.1_Xerus_rutilus_HiC No NEAT start
# GCA_028646385.1_Steno_bredanensis_HiC No NEAT stop
# GCA_028646425.1_Grampus_griseus_HiC No NEAT start
# GCA_028646515.1_Pseudochirops_corinnae_HiC No MALAT start
# GCA_028646535.1_pl-1k No NEAT stop
# GCA_028646575.1_Pseudocheirus_occidentalis_HiC No NEAT start
# GCA_028646595.1_pg-2k No MALAT start
# GCA_028658305.1_Pachyuromys_duprasi_HiC No MALAT start
# GCA_028658325.1_Potorous_gilbertii_HiC No MALAT start
# GCA_029224305.1_Cmar_C18_SBIK-F_TBG_1 No NEAT start
# GCA_029224305.1_Cmar_C18_SBIK-F_TBG_1 No NEAT stop
# GCA_029224305.1_Cmar_C18_SBIK-F_TBG_1 No MALAT stop
# GCA_029532125.1_Ltowsendii_DMNS18807_Prim_1.0 No NEAT start
# GCA_029532125.1_Ltowsendii_DMNS18807_Prim_1.0 No MALAT start
# GCA_029593785.1_MVZ_CabUni_1.0 No NEAT start
# GCA_029593785.1_MVZ_CabUni_1.0 No MALAT start
# GCA_029593785.1_MVZ_CabUni_1.0 No NEAT stop
# GCA_029958975.1_ASM2995897v1 No MALAT start
# GCA_030035585.1_mDugDug1.hap1 No MALAT start
# GCA_900006375.2_Gulo_2.2_annotated No NEAT start
# GCA_900006375.2_Gulo_2.2_annotated No NEAT stop
# GCA_900661375.1_LYPA1.0 No NEAT stop
# GCA_902168325.1_Pnud_10x_v1 No NEAT start
# GCA_902168325.1_Pnud_10x_v1 No MALAT start
# GCA_902168325.1_Pnud_10x_v1 No NEAT stop
# GCA_902168325.1_Pnud_10x_v1 No MALAT stop
# GCA_902168405.1_Pazt_10x_v1 No NEAT start
# GCA_902168405.1_Pazt_10x_v1 No MALAT start
# GCA_902168405.1_Pazt_10x_v1 No NEAT stop
# GCA_902168405.1_Pazt_10x_v1 No MALAT stop
# GCA_902168415.1_Pmel_10x_v1 No NEAT start
# GCA_902168415.1_Pmel_10x_v1 No MALAT start
# GCA_902168415.1_Pmel_10x_v1 No NEAT stop
# GCA_902168415.1_Pmel_10x_v1 No MALAT stop
# GCA_902168425.1_Patt_10x_v1 No NEAT start
# GCA_902168425.1_Patt_10x_v1 No MALAT start
# GCA_902168425.1_Patt_10x_v1 No NEAT stop
# GCA_902168425.1_Patt_10x_v1 No MALAT stop
# GCA_902729485.2_Mus_minutoides_I2396_v1 No NEAT start
# GCA_902729485.2_Mus_minutoides_I2396_v1 No NEAT stop
# GCA_903992545.1_mPipPip1.1 No NEAT start
# GCA_903992545.1_mPipPip1.1 No MALAT start
# GCA_903992545.1_mPipPip1.1 No NEAT stop
# GCA_903992545.1_mPipPip1.1 No MALAT stop
# GCA_905146905.1_NYPRO_anot_genome No MALAT start
# GCA_907164565.1_mPsaObe1.curated_primary_1811 No MALAT start
# GCA_949987585.1_mPipPyg2.1 No NEAT start
# GCF_000001905.1_Loxafr3.0 No NEAT start
# GCF_000002285.5_Dog10K_Boxer_Tasha No MALAT start
# GCF_000002295.2_MonDom5 No MALAT start
# GCF_000002295.2_MonDom5 No NEAT stop
# GCF_000002295.2_MonDom5 No MALAT stop
# GCF_000003625.3_OryCun2.0 No NEAT start
# GCF_000003625.3_OryCun2.0 No MALAT start
# GCF_000147115.1_Myoluc2.0 No NEAT start
# GCF_000151735.1_Cavpor3.0 No MALAT start
# GCF_000151845.1_Pvam_2.0 No MALAT start
# GCF_000164805.1_Tarsius_syrichta-2.0.1 No NEAT start
# GCF_000164805.1_Tarsius_syrichta-2.0.1 No NEAT stop
# GCF_000165445.2_Mmur_3.0 No MALAT start
# GCF_000208655.1_Dasnov3.0 No MALAT start
# GCF_000223135.1_CriGri_1.0 No MALAT stop
# GCF_000260355.1_ConCri1.0 No NEAT start
# GCF_000296755.1_EriEur2.0 No MALAT start
# GCF_000299155.1_EleEdw1.0 No MALAT start
# GCF_000313985.2_ASM31398v2 No MALAT start
# GCF_000325575.1_ASM32557v1 No MALAT start
# GCF_000327345.1_ASM32734v1 No NEAT start
# GCF_000412655.1_ASM41265v1 No NEAT start
# GCF_000622305.1_S.galili_v1.0 No MALAT start
# GCF_000696695.1_Burgud No NEAT start
# GCF_000754665.1_Bison_UMD1.0 No NEAT start
# GCF_000754665.1_Bison_UMD1.0 No NEAT stop
# GCF_001458135.1_marMar2.1 No NEAT start
# GCF_002099425.1_phaCin_unsw_v4.1 No MALAT start
# GCF_002204375.1_MunDraft-v1.0 No MALAT start
# GCF_003255815.1_Tgel_1.0 No NEAT stop
# GCF_006229205.1_meerkat_22Aug2017_6uvM2_HiC No MALAT start
# GCF_012274545.1_DMR_v1.0_HiC No MALAT start
# GCF_012295265.1_UNSW_AlpineDingo_1.0 No MALAT start
# GCF_014108245.1_mPipKuh1.p No NEAT start
# GCF_014441545.1_ROS_Cfam_1.0 No MALAT start
# GCF_014570535.1_YNU_ManJav_2.0 No MALAT stop
# GCF_014570555.1_YNU_ManPten_2.0 No MALAT stop
# GCF_014633375.1_OchPri4.0 No MALAT start
# GCF_014824575.2_WHU_Shon_v2.1 No MALAT start
# GCF_015220235.1_mChoDid1.pri No MALAT start
# GCF_015852505.1_mTacAcu1.pri No MALAT start
# GCF_016433145.1_AgileGrace No MALAT start
# GCF_017591425.1_NIBS_Ocur_1.0 No MALAT start
# GCF_018350155.1_O.geoffroyi_Oge1_pat1.0 No MALAT stop
# GCF_019393635.1_mDroGli1.pri No MALAT start
# GCF_900094665.1_CAROLI_EIJ_v1.1 No MALAT stop
# GCF_902635505.1_mSarHar1.11 No MALAT start
# GCF_902729225.1_Ma_sr-lr_union100 No MALAT start

# %%
# collect genomes without start or stop coordinates
left = []
for lib in NEAT:
    if not 'start' in NEAT[lib] or not 'stop' in NEAT[lib]:
        left.append(lib)

# Check for long (> 5kb) homology patches between known orthologs
# and genomic assemblies lacking stop or start (or both) coordinates

manual = []
for lib in left:
    with open('./BLAST_features/' + lib + '.txt') as file1:
        for line in file1:
            dat = line.strip().split('\t')
            if int(dat[2]) > 5000:
                manual.append(lib)
                break
                
print(len(manual), len(left))

#keep for the analysis only assemblies with clear homology
to_exclude = [i for i in left if i not in manual]
# Out:
# 83 171

# %%
#write into file the results of coordinates search

#GenomeID Neat1ContigAccession Neat1Start Neat1Stop Neat1ApproxLength Malat1ContigAccession Malat1Start
#Malat1Stop Malat1ApproxLength

#GCA_000283155.1_CerSimSim1.0	JH767791.1	9929556	9952059	22503	JH767791.1	9997904	10005062	7158

out = open('coordinates_algorithmic','w')
for lib in libs:
    if lib not in to_exclude:
        l = [lib]
        if lib in NEAT:
            l.append(NEAT[lib]['contig'])
            if 'start' in NEAT[lib]:
                l.append(NEAT[lib]['start'])
            else:
                l.append('Nan')

            if 'stop' in NEAT[lib]:
                l.append(NEAT[lib]['stop'])
            else:
                l.append('Nan')
            if 'start' in NEAT[lib] and 'stop' in NEAT[lib]:
                l.append(str(abs(int(NEAT[lib]['start']) - int(NEAT[lib]['stop']))))
            else:
                l.append('Nan')
        else:
            l += ['Nan','Nan','Nan']
        if lib in MALAT:
            l.append(MALAT[lib]['contig'])
            if 'start' in MALAT[lib]:
                l.append(MALAT[lib]['start'])
            else:
                l.append('Nan')

            if 'stop' in MALAT[lib]:
                l.append(MALAT[lib]['stop'])
            else:
                l.append('Nan')
            if 'start' in MALAT[lib] and 'stop' in MALAT[lib]:
                l.append(str(abs(int(MALAT[lib]['start']) - int(MALAT[lib]['stop']))))
            else:
                l.append('Nan')
        else:
            l += ['Nan','Nan','Nan']
        out.write('\t'.join(l) + '\n')

out.close()

# %% [markdown]
# ### Manual curation of approximate coordinates
# After that we performed a manual curation of the cases where start or stop coordinate was missing by looking at the results of blastn search. In some cases the contig assembly was incomplete and a gene was lacking 5' or 3' end, if the majority of the gene was preserved we set the missing coordinate to 0 and kept the ortholog in the dataset. In other cases we could clearly see many patches of homology to known orthologs and only the promotor area did not give the hit in blastn search; if we could approximate the location of the ortholog, we set the start coordinate manually.

# %% [markdown]
# ### Assigning taxonomic tree to the species with identified orthologs after manual curation

# %%
# ManualCuration file is the 'coordinates_algorithmic' after manually added start/stop coordinates
sel = {}
with open('ManualCuration') as file1:
    for line in file1:
        if not line.startswith('#'):
            dat = line.strip().split('\t')
            sel[dat[0]] = {}
            sel[dat[0]]['coor'] = dat[1:]
print(len(sel))
# Out:
# 544

# %%
#Names of known NEAT1 and MALAT1 orthologs
ref_names = ['NEAT1_Mouse','NEAT1_Marsupials','NEAT1_Human','MALAT1_Mouse','MALAT1_Human']

# %%
# Retrieve taxid for mammals with identified orthologs
with open('Namesystem') as file1:
    for line in file1:
        dat = line.strip().split('\t')
        if dat[0] in sel:
            sel[dat[0]]['sc_name'] = dat[1]
            sel[dat[0]]['taxid'] = dat[2]
        if dat[0] in ref_names:
            sel[dat[0]] = {}
            sel[dat[0]]['sc_name'] = dat[1]
            sel[dat[0]]['taxid'] = dat[2] 
taxid_list = [sel[i]['taxid'] for i in sel]

# %% [markdown]
# Below files (*.dpm) are part of the taxonomy package from NCBI
# https://ftp.ncbi.nlm.nih.gov/pub/taxonomy/taxdump.tar.gz

# %%
#Function to loop through the taxonomy tree
def parse_nodes(taxid, data_dict):
    if taxid in parent_dict and taxid in rank_dict:
        while parent_dict[taxid] != taxid:
            data_dict[rank_dict[taxid]] = names_dict[taxid]
            taxid = parent_dict[taxid]
    else:
          data_dict = {}  
    return(data_dict)
categories = ["species", "genus", "family", "order", "class"]

# %%
# Collect common and scientific names from NCBI files and hierarchy of taxa
comname = {}
rank_dict = {}
parent_dict = {}
names_dict = {}
with open('/home/ksenia/databases/Taxonomy/names.dmp') as names_file:
    names = csv.reader(names_file,delimiter='\t',quoting=csv.QUOTE_NONE)     
    for line in names:
        if line[6] == 'scientific name':
            names_dict[line[0]] = line[2]
        if 'common name' in line[6]:
            if line[0] in taxid_list:
                comname[line[0]] = line[2]

with open('/home/ksenia/databases/Taxonomy/nodes.dmp','r')as nodes_file:
    nodes = csv.reader(nodes_file,delimiter='\t',quoting=csv.QUOTE_NONE)
    for line in nodes:
        parent_dict[line[0]] = line[2]
        rank_dict[line[0]] = line[4]

# %%
# Build a taxonomy tree for individual genome of our collection
taxonomy = {}
for item in taxid_list:
    taxonomy[item] = {}
    z = parse_nodes(item, {})
    if z:
        for cat in categories:
            if cat in z.keys():
                taxonomy[item][cat] = z[cat] 
            else:
                taxonomy[item][cat] = 'NA'
    else:
        for cat in categories:
            taxonomy[item][cat] = 'NA'

# %%
# Create the first metadata file
out = open('./Key_Files/Metadata','w')
out.write('#File_name\tScientific_name\tCommon_name\ttaxid\t' + '\t'.join(categories[::-1]) + 
          'NEAT1Contig\tNEAT1start\tNEAT1stop\t' + 
          'MALAT1Contig\tMALAT1start\tMALAT1stop\n')
for item in sel:
    l = [item, sel[item]['sc_name']]
    if sel[item]['taxid'] in comname:
        l.append(comname[sel[item]['taxid']])
    else:
        l.append('Nan')
    l.append(sel[item]['taxid'])
    for cat in categories[::-1]:
        l.append(taxonomy[sel[item]['taxid']][cat])
    l += sel[item]['coor']
    out.write('\t'.join(l) + '\n')
    
out.close()
